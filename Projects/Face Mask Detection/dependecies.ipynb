# %%
# !pip install Py-OS
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Running setup.py install for Py-OS: started
#   Running setup.py install for Py-OS: finished with status 'done'
# ...
#   DEPRECATION: Py-OS is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559

# %%
# !pip install wheel

# %%
# !pip install numpy
# Out:
# ...
#   Using cached numpy-1.24.2-cp38-cp38-win_amd64.whl (14.9 MB)
# ...

# %%
# !pip install random2
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for random2: filename=random2-1.0.1-py3-none-any.whl size=12086 sha256=e8e6fe37e42696f64879c0981f56629d283362cfcd24fc8205bdb7b9a6460b4a
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\6e\ca\f2\082dec051ffcaec249ae491b8c90e305726a7390274682b4a4
# Successfully built random2
# ...

# %%
# !pip install glob2
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for glob2: filename=glob2-0.7-py2.py3-none-any.whl size=9319 sha256=2138dbf1e10d3570922c66e9a4915e377777a20ae1ce62a3ded4b58fc1a3670e
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\95\59\ed\52469ecfae47a78c25f11bcb49db42ff84629df01861876883
# Successfully built glob2
# ...

# %%
# !pip install opencv-python
# Out:
# ...
#      ---------------------------------------- 0.0/38.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/38.2 MB ? eta -:--:--
#      ---------------------------------------- 0.1/38.2 MB 1.2 MB/s eta 0:00:33
#      ---------------------------------------- 0.1/38.2 MB 1.0 MB/s eta 0:00:37
#      ---------------------------------------- 0.2/38.2 MB 1.1 MB/s eta 0:00:37
#      ---------------------------------------- 0.2/38.2 MB 1.1 MB/s eta 0:00:37
#      --------------------------------------- 0.2/38.2 MB 734.2 kB/s eta 0:00:52
#      --------------------------------------- 0.2/38.2 MB 734.2 kB/s eta 0:00:52
#      --------------------------------------- 0.2/38.2 MB 686.6 kB/s eta 0:00:56
#      --------------------------------------- 0.4/38.2 MB 908.0 kB/s eta 0:00:42
#      --------------------------------------- 0.4/38.2 MB 908.0 kB/s eta 0:00:42
#      --------------------------------------- 0.4/38.2 MB 839.7 kB/s eta 0:00:45
# ...

# %%
# !pip install scikit-learn
# Out:
# ...
#      ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/8.3 MB 1.9 MB/s eta 0:00:05
#      ---------------------------------------- 0.1/8.3 MB 1.7 MB/s eta 0:00:05
#       --------------------------------------- 0.1/8.3 MB 819.2 kB/s eta 0:00:10
#       --------------------------------------- 0.2/8.3 MB 952.6 kB/s eta 0:00:09
#      - -------------------------------------- 0.3/8.3 MB 1.2 MB/s eta 0:00:07
#      - -------------------------------------- 0.4/8.3 MB 1.4 MB/s eta 0:00:06
#      -- ------------------------------------- 0.5/8.3 MB 1.5 MB/s eta 0:00:06
#      -- ------------------------------------- 0.5/8.3 MB 1.5 MB/s eta 0:00:06
#      --- ------------------------------------ 0.6/8.3 MB 1.6 MB/s eta 0:00:05
#      --- ------------------------------------ 0.7/8.3 MB 1.6 MB/s eta 0:00:05
#      --- ------------------------------------ 0.8/8.3 MB 1.6 MB/s eta 0:00:05
# ...

# %%
# !pip install keras
# Out:
# ...
#      ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#       --------------------------------------- 0.0/1.7 MB 1.3 MB/s eta 0:00:02
#       --------------------------------------- 0.0/1.7 MB 1.3 MB/s eta 0:00:02
#      --- ------------------------------------ 0.1/1.7 MB 944.1 kB/s eta 0:00:02
#      ---- ----------------------------------- 0.2/1.7 MB 1.4 MB/s eta 0:00:02
#      ------- -------------------------------- 0.3/1.7 MB 1.4 MB/s eta 0:00:02
#      ------------ --------------------------- 0.5/1.7 MB 2.0 MB/s eta 0:00:01
#      ------------ --------------------------- 0.5/1.7 MB 2.0 MB/s eta 0:00:01
#      -------------- ------------------------- 0.6/1.7 MB 1.7 MB/s eta 0:00:01
#      ----------------- ---------------------- 0.8/1.7 MB 1.8 MB/s eta 0:00:01
#      --------------------- ------------------ 0.9/1.7 MB 2.0 MB/s eta 0:00:01
#      ------------------------ --------------- 1.0/1.7 MB 2.0 MB/s eta 0:00:01
# ...

# %%
# !pip install tensorflow
# Out:
# ...
#      ---------------------------------------- 0.0/266.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/266.3 MB 2.0 MB/s eta 0:02:11
#      ---------------------------------------- 0.1/266.3 MB 2.4 MB/s eta 0:01:49
#      ---------------------------------------- 0.3/266.3 MB 2.7 MB/s eta 0:01:38
#      ---------------------------------------- 0.3/266.3 MB 2.7 MB/s eta 0:01:38
#      ---------------------------------------- 0.4/266.3 MB 1.8 MB/s eta 0:02:26
#      ---------------------------------------- 0.5/266.3 MB 2.1 MB/s eta 0:02:07
#      ---------------------------------------- 0.7/266.3 MB 2.1 MB/s eta 0:02:07
#      ---------------------------------------- 0.8/266.3 MB 2.3 MB/s eta 0:01:55
#      ---------------------------------------- 0.9/266.3 MB 2.5 MB/s eta 0:01:47
#      ---------------------------------------- 0.9/266.3 MB 2.5 MB/s eta 0:01:47
#      ---------------------------------------- 0.9/266.3 MB 1.8 MB/s eta 0:02:26
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#      ---------------------------------------- 0.1/7.6 MB 1.5 MB/s eta 0:00:05
#       --------------------------------------- 0.1/7.6 MB 1.8 MB/s eta 0:00:05
#      - -------------------------------------- 0.3/7.6 MB 1.9 MB/s eta 0:00:04
#      -- ------------------------------------- 0.4/7.6 MB 2.3 MB/s eta 0:00:04
#      -- ------------------------------------- 0.5/7.6 MB 2.4 MB/s eta 0:00:03
#      --- ------------------------------------ 0.7/7.6 MB 2.5 MB/s eta 0:00:03
#      --- ------------------------------------ 0.8/7.6 MB 2.3 MB/s eta 0:00:04
#      ---- ----------------------------------- 0.9/7.6 MB 2.5 MB/s eta 0:00:03
#      ----- ---------------------------------- 1.0/7.6 MB 2.4 MB/s eta 0:00:03
#      ----- ---------------------------------- 1.1/7.6 MB 2.4 MB/s eta 0:00:03
#      ------ --------------------------------- 1.3/7.6 MB 2.5 MB/s eta 0:00:03
# ...
